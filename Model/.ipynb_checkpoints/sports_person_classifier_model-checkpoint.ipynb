# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread('./dataset/brian lara/lara_001.jpg')

# %%
plt.imshow(img)

# %%
import numpy as np
import cv2

img = cv2.imread('./dataset/brian lara/lara_001.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4cc46afd47bb> in <module>
#       4 img = cv2.imread('./dataset/brian lara/lara_001.jpg')
#       5 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 6 faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       7 faces
#
# NameError: name 'face_cascade' is not defined

# %%
plt.imshow(img)

# %%
(x,y,w,h)=faces[0]
x,y,w,h
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ec5f5c8e41f6> in <module>
# ----> 1 (x,y,w,h)=faces[0]
#       2 x,y,w,h
#
# NameError: name 'faces' is not defined

# %%
face_img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),6)
plt.imshow(face_img,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-455501fd99e3> in <module>
# ----> 1 face_img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),6)
#       2 plt.imshow(face_img,cmap='gray')
#
# NameError: name 'x' is not defined

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),7)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)

    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),3)

plt.figure()
plt.imshow(face_img,cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4e7559c679d0> in <module>
#       1 cv2.destroyAllWindows()
# ----> 2 for (x,y,w,h) in faces:
#       3     face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),7)
#       4     roi_gray = gray[y:y+h, x:x+w]
#       5     roi_color = face_img[y:y+h, x:x+w]
#
# NameError: name 'faces' is not defined

# %%
plt.imshow(roi_color,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0c1b04868c1b> in <module>
# ----> 1 plt.imshow(roi_color,cmap='gray')
#
# NameError: name 'roi_color' is not defined

# %%
def get_cropped_image_if_2_eyes(image_path):
    img=cv2.imread(image_path)
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_cascade.detectMultiScale(gray,1.3,5)
    for (x,y,w,h) in faces:
        roi_gray=gray[y:y+h,x:x+w]
        roi_color=img[y:y+h,x:x+w]
        eyes=eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 1:
            return roi_color

# %%
original_image=cv2.imread('./dataset/kapil dev/kapil_008.jpg')
plt.imshow(original_image)

# %%
cropped_image=get_cropped_image_if_2_eyes('./dataset/kapil dev/kapil_001.jpg')
cropped_image
# Out:
# array([[[212, 193, 188],
#         [216, 197, 192],
#         [187, 173, 167],
#         ...,
#         [  4,   5,   3],
#         [  3,   4,   2],
#         [  3,   4,   2]],
#
#        [[223, 204, 199],
#         [220, 201, 196],
#         [176, 162, 156],
#         ...,
#         [  4,   5,   3],
#         [  3,   4,   2],
#         [  3,   4,   2]],
#
#        [[224, 205, 200],
#         [220, 201, 196],
#         [186, 172, 166],
#         ...,
#         [  4,   5,   3],
#         [  3,   4,   2],
#         [  3,   4,   2]],
#
#        ...,
#
#        [[245, 242, 244],
#         [248, 245, 247],
#         [250, 247, 249],
#         ...,
#         [ 83,  90, 105],
#         [ 81,  88, 103],
#         [ 79,  86, 101]],
#
#        [[245, 242, 244],
#         [247, 244, 246],
#         [250, 247, 249],
#         ...,
#         [ 82,  89, 104],
#         [ 81,  88, 103],
#         [ 80,  87, 102]],
#
#        [[244, 241, 243],
#         [247, 244, 246],
#         [249, 246, 248],
#         ...,
#         [ 80,  87, 102],
#         [ 81,  88, 103],
#         [ 82,  89, 104]]], dtype=uint8)

# %%
path_to_data="./dataset/"
path_to_cr_data="./dataset/cropped/"

# %%
import os
img_dirs=[]
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/brian lara',
#  './dataset/kapil dev',
#  './dataset/maria sharapova',
#  './dataset/roger federer',
#  './dataset/virat kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs=[]
celebrity_file_names_dict={}

for img_dir in img_dirs:
    count=1
    celebrity_name=img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name]=[]
    
    for entry in os.scandir(img_dir):
        roi_color=get_cropped_image_if_2_eyes(entry.path)
        print(roi_color)
        if roi_color is not None:
            cropped_folder=path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder :",cropped_folder)
            cropped_file_name=celebrity_name + str(count) + ".png"
            print(cropped_file_name)
            cropped_file_path=cropped_folder + "/" + cropped_file_name
            print(cropped_file_path)
            
            cv2.imwrite(cropped_file_path,roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count+=1
# Out:
# brian lara
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [[[185 188 179]
#   [196 197 187]
#   [189 190 180]
#   ...
#   [198 196 195]
#   [197 195 194]
#   [190 190 190]]
#
#  [[186 189 180]
#   [194 195 185]
#   [196 197 187]
#   ...
#   [199 197 196]
#   [198 196 195]
#   [193 193 193]]
#
#  [[187 190 181]
#   [189 190 181]
#   [192 193 184]
#   ...
#   [200 198 197]
#   [199 197 196]
#   [197 197 197]]
#
#  ...
#
#  [[ 52  47 126]
#   [ 10  11  67]
#   [ 53  56 100]
#   ...
#   [214 215 213]
#   [214 215 213]
#   [217 218 216]]
#
#  [[ 48  42 124]
#   [ 46  45 109]
#   [ 31  32  83]
#   ...
#   [213 214 212]
#   [213 214 212]
#   [215 216 214]]
#
#  [[ 49  41 128]
#   [ 43  39 110]
#   [ 45  43 103]
#   ...
#   [213 214 212]
#   [213 214 212]
#   [214 215 213]]]
# Generating cropped images in folder : ./dataset/cropped/brian lara
# brian lara1.png
# ./dataset/cropped/brian lara/brian lara1.png
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [[[183 199 205]
#   [183 199 205]
#   [183 199 205]
#   ...
#   [ 49  62  76]
#   [ 30  42  54]
#   [ 37  49  59]]
#
#  [[185 199 205]
#   [185 199 205]
#   [187 201 207]
#   ...
#   [ 41  56  72]
#   [ 36  50  62]
#   [ 41  53  63]]
#
#  [[185 199 205]
#   [185 199 205]
#   [187 201 207]
#   ...
#   [ 42  58  74]
#   [ 33  49  61]
#   [ 31  46  55]]
#
#  ...
#
#  [[186 201 204]
#   [185 200 203]
#   [187 202 205]
#   ...
#   [ 59  83 119]
#   [ 66  92 128]
#   [ 70  98 129]]
#
#  [[186 201 203]
#   [186 201 203]
#   [188 201 203]
#   ...
#   [ 62  88 125]
#   [ 67  94 131]
#   [ 69  96 130]]
#
#  [[186 201 203]
#   [186 201 203]
#   [184 197 199]
#   ...
#   [ 64  91 128]
#   [ 69  95 135]
#   [ 68  94 130]]]
# brian lara2.png
# ./dataset/cropped/brian lara/brian lara2.png
# None
# None
# None
# None
# None
# None
# [[[179 182 173]
#   [180 183 174]
#   [188 191 182]
#   ...
#   [189 190 188]
#   [187 188 186]
#   [184 187 185]]
#
#  [[180 182 176]
#   [180 182 176]
#   [181 183 177]
#   ...
#   [192 188 187]
#   [193 189 188]
#   [192 188 187]]
#
#  [[182 185 176]
#   [181 184 175]
#   [182 185 176]
#   ...
#   [189 185 184]
#   [190 186 185]
#   [191 187 186]]
#
#  ...
#
#  [[ 35  22 130]
#   [ 40  27 135]
#   [ 50  37 145]
#   ...
#   [218 222 216]
#   [216 220 215]
#   [212 216 211]]
#
#  [[ 38  27 131]
#   [ 17   6 110]
#   [ 33  21 127]
#   ...
#   [212 216 210]
#   [214 218 213]
#   [212 216 211]]
#
#  [[ 51  41 141]
#   [ 35  24 126]
#   [ 29  18 120]
#   ...
#   [216 220 214]
#   [215 219 214]
#   [212 216 211]]]
# brian lara3.png
# ./dataset/cropped/brian lara/brian lara3.png
# None
# None
# [[[ 89  95 102]
#   [126 132 139]
#   [132 136 141]
#   ...
#   [125 110 107]
#   [125 110 107]
#   [125 110 107]]
#
#  [[117 123 130]
#   [ 72  78  85]
#   [141 145 150]
#   ...
#   [125 110 107]
#   [125 110 107]
#   [126 111 108]]
#
#  [[169 175 180]
#   [ 96 102 107]
#   [152 158 163]
#   ...
#   [125 110 107]
#   [126 111 108]
#   [126 111 108]]
#
#  ...
#
#  [[167 163 158]
#   [196 193 188]
#   [246 243 238]
#   ...
#   [214 222 222]
#   [220 225 223]
#   [226 229 227]]
#
#  [[180 177 172]
#   [221 218 213]
#   [255 255 251]
#   ...
#   [213 221 221]
#   [219 224 222]
#   [228 231 229]]
#
#  [[212 209 204]
#   [245 245 239]
#   [253 253 247]
#   ...
#   [209 217 217]
#   [214 219 217]
#   [227 230 228]]]
# brian lara4.png
# ./dataset/cropped/brian lara/brian lara4.png
# [[[142 146 174]
#   [142 145 176]
#   [141 144 175]
#   ...
#   [150 122 122]
#   [154 124 123]
#   [154 124 123]]
#
#  [[139 143 172]
#   [138 141 172]
#   [137 140 171]
#   ...
#   [151 123 123]
#   [154 124 123]
#   [154 124 123]]
#
#  [[139 143 172]
#   [137 140 171]
#   [136 139 170]
#   ...
#   [152 124 124]
#   [154 124 123]
#   [154 124 123]]
#
#  ...
#
#  [[ 67  80 102]
#   [ 69  82 104]
#   [ 71  84 106]
#   ...
#   [ 46  46  46]
#   [ 35  34  36]
#   [ 35  34  36]]
#
#  [[ 67  80 102]
#   [ 68  81 103]
#   [ 70  83 105]
#   ...
#   [ 39  39  39]
#   [ 34  33  37]
#   [ 35  34  38]]
#
#  [[ 66  79 101]
#   [ 67  80 102]
#   [ 69  82 104]
#   ...
#   [ 32  32  32]
#   [ 34  33  37]
#   [ 34  33  37]]]
# brian lara5.png
# ./dataset/cropped/brian lara/brian lara5.png
# None
# None
# None
# [[[124 114 130]
#   [124 114 130]
#   [123 114 127]
#   ...
#   [ 89  89 101]
#   [ 93  93 105]
#   [101 101 113]]
#
#  [[119 111 128]
#   [118 111 126]
#   [118 111 126]
#   ...
#   [ 86  86  98]
#   [ 83  83  95]
#   [ 93  93 105]]
#
#  [[114 108 125]
#   [114 109 124]
#   [113 108 123]
#   ...
#   [ 86  86  98]
#   [ 75  75  87]
#   [ 82  82  94]]
#
#  ...
#
#  [[233 231 230]
#   [248 246 246]
#   [238 236 236]
#   ...
#   [ 61  70  83]
#   [ 60  69  82]
#   [ 59  68  81]]
#
#  [[229 227 227]
#   [238 236 236]
#   [235 233 233]
#   ...
#   [ 62  69  84]
#   [ 60  69  83]
#   [ 58  67  81]]
#
#  [[228 226 226]
#   [233 231 231]
#   [234 232 231]
#   ...
#   [ 61  68  83]
#   [ 58  67  81]
#   [ 57  66  80]]]
# brian lara6.png
# ./dataset/cropped/brian lara/brian lara6.png
# [[[ 97 103 170]
#   [ 94 100 167]
#   [101 106 175]
#   ...
#   [136 103 117]
#   [138 105 119]
#   [139 106 120]]
#
#  [[101 104 172]
#   [ 99 105 172]
#   [108 110 180]
#   ...
#   [136 103 117]
#   [138 105 119]
#   [139 106 120]]
#
#  [[105 106 174]
#   [105 108 176]
#   [113 114 182]
#   ...
#   [136 103 117]
#   [138 105 119]
#   [139 106 120]]
#
#  ...
#
#  [[124 108 172]
#   [126 110 174]
#   [120 105 167]
#   ...
#   [203 164 180]
#   [204 165 181]
#   [204 165 181]]
#
#  [[126 109 173]
#   [130 113 177]
#   [123 106 170]
#   ...
#   [203 164 180]
#   [204 165 181]
#   [204 165 181]]
#
#  [[131 114 178]
#   [131 114 178]
#   [126 109 173]
#   ...
#   [203 164 180]
#   [204 165 181]
#   [204 165 181]]]
# brian lara7.png
# ./dataset/cropped/brian lara/brian lara7.png
# kapil dev
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [[[ 33  32  28]
#   [ 46  42  41]
#   [ 40  34  35]
#   ...
#   [  9   8  18]
#   [  6   5  15]
#   [  6   5  15]]
#
#  [[ 27  28  26]
#   [ 37  34  36]
#   [ 44  37  44]
#   ...
#   [  5   4  14]
#   [ 10   9  19]
#   [ 11  10  20]]
#
#  [[ 24  28  29]
#   [ 36  34  46]
#   [ 48  44  63]
#   ...
#   [  5   4  14]
#   [  0   0   7]
#   [  0   0   9]]
#
#  ...
#
#  [[ 60  70  87]
#   [ 13  19  26]
#   [ 34  35  39]
#   ...
#   [ 11  20  30]
#   [  9  14  23]
#   [ 17  23  30]]
#
#  [[122 133 147]
#   [  0   0   3]
#   [ 34  32  31]
#   ...
#   [ 17  24  33]
#   [ 13  17  22]
#   [ 16  20  25]]
#
#  [[188 200 212]
#   [ 14  16  17]
#   [ 40  36  31]
#   ...
#   [ 24  30  37]
#   [ 17  21  26]
#   [ 17  20  24]]]
# Generating cropped images in folder : ./dataset/cropped/kapil dev
# kapil dev1.png
# ./dataset/cropped/kapil dev/kapil dev1.png
# [[[225 171 138]
#   [227 173 140]
#   [230 176 143]
#   ...
#   [ 74  76  76]
#   [107 109 109]
#   [145 147 147]]
#
#  [[225 171 138]
#   [227 173 140]
#   [229 175 142]
#   ...
#   [120 122 122]
#   [ 74  76  76]
#   [130 132 132]]
#
#  [[227 173 140]
#   [228 174 141]
#   [230 176 143]
#   ...
#   [ 76  78  78]
#   [ 71  73  73]
#   [111 113 113]]
#
#  ...
#
#  [[163 231 220]
#   [162 230 219]
#   [164 230 219]
#   ...
#   [239 221 168]
#   [244 228 175]
#   [242 230 176]]
#
#  [[174 238 226]
#   [173 237 225]
#   [172 234 222]
#   ...
#   [238 221 165]
#   [238 223 167]
#   [241 229 175]]
#
#  [[178 237 223]
#   [179 235 222]
#   [178 232 219]
#   ...
#   [240 223 167]
#   [236 221 165]
#   [247 235 181]]]
# kapil dev2.png
# ./dataset/cropped/kapil dev/kapil dev2.png
# [[[147 156 130]
#   [160 169 142]
#   [141 151 121]
#   ...
#   [ 71  79  62]
#   [ 26  33  18]
#   [ 37  44  31]]
#
#  [[146 152 127]
#   [152 159 132]
#   [124 132 102]
#   ...
#   [ 97 105  88]
#   [ 30  37  22]
#   [ 24  31  18]]
#
#  [[120 126 101]
#   [109 116  89]
#   [137 145 115]
#   ...
#   [ 84  92  75]
#   [ 45  52  37]
#   [ 11  18   5]]
#
#  ...
#
#  [[ 11  26  12]
#   [134 151 130]
#   [147 164 137]
#   ...
#   [ 14  15   6]
#   [ 16  17   8]
#   [ 18  19  10]]
#
#  [[144 155 139]
#   [120 133 111]
#   [119 132 106]
#   ...
#   [ 14  15   6]
#   [ 16  17   8]
#   [ 17  18   9]]
#
#  [[133 144 124]
#   [133 140 119]
#   [127 135 112]
#   ...
#   [ 14  15   6]
#   [ 15  16   7]
#   [ 17  18   9]]]
# kapil dev3.png
# ./dataset/cropped/kapil dev/kapil dev3.png
# [[[ 69  71  71]
#   [ 98 100 100]
#   [101 103 103]
#   ...
#   [ 35  36  40]
#   [ 39  40  44]
#   [ 31  32  36]]
#
#  [[ 72  74  74]
#   [ 48  50  50]
#   [ 49  51  51]
#   ...
#   [ 34  35  39]
#   [ 36  37  41]
#   [ 31  32  36]]
#
#  [[ 76  78  78]
#   [ 55  57  57]
#   [ 48  50  50]
#   ...
#   [ 37  38  42]
#   [ 37  38  42]
#   [ 33  34  38]]
#
#  ...
#
#  [[ 82  88  87]
#   [101 109 108]
#   [ 86  94  93]
#   ...
#   [ 11  11  17]
#   [ 11  11  17]
#   [ 11  11  17]]
#
#  [[121 128 125]
#   [112 120 119]
#   [ 87  98  96]
#   ...
#   [ 11  11  17]
#   [ 11  11  17]
#   [ 11  11  17]]
#
#  [[100 109 106]
#   [ 87  98  96]
#   [ 94 105 103]
#   ...
#   [ 11  11  17]
#   [ 11  11  17]
#   [ 11  11  17]]]
# kapil dev4.png
# ./dataset/cropped/kapil dev/kapil dev4.png
# None
# None
# [[[ 41  35  46]
#   [ 28  23  32]
#   [ 23  18  27]
#   ...
#   [  7   6  15]
#   [ 14  12  18]
#   [ 25  21  26]]
#
#  [[ 32  28  40]
#   [ 23  17  28]
#   [ 22  17  26]
#   ...
#   [ 21  19  31]
#   [ 19  15  26]
#   [ 26  23  32]]
#
#  [[ 22  17  32]
#   [ 33  27  38]
#   [ 35  30  39]
#   ...
#   [ 31  28  43]
#   [ 31  27  39]
#   [ 27  23  34]]
#
#  ...
#
#  [[ 76  65  91]
#   [ 81  68  94]
#   [ 81  68  94]
#   ...
#   [ 16  13  15]
#   [ 19  16  18]
#   [ 22  19  21]]
#
#  [[ 81  72  99]
#   [ 83  71  99]
#   [ 85  71  99]
#   ...
#   [ 17  14  16]
#   [ 23  20  22]
#   [ 29  27  27]]
#
#  [[ 82  78 107]
#   [ 83  73 103]
#   [ 85  73 103]
#   ...
#   [ 17  14  16]
#   [ 27  24  26]
#   [ 34  32  32]]]
# kapil dev5.png
# ./dataset/cropped/kapil dev/kapil dev5.png
# None
# None
# None
# [[[ 90  90  90]
#   [ 67  67  67]
#   [ 64  64  64]
#   ...
#   [ 45  45  45]
#   [ 48  48  48]
#   [ 58  58  58]]
#
#  [[ 91  91  91]
#   [ 71  71  71]
#   [ 69  69  69]
#   ...
#   [ 56  56  56]
#   [ 54  54  54]
#   [ 53  53  53]]
#
#  [[ 92  92  92]
#   [ 75  75  75]
#   [ 69  69  69]
#   ...
#   [ 60  60  60]
#   [ 58  58  58]
#   [ 57  57  57]]
#
#  ...
#
#  [[245 245 245]
#   [244 244 244]
#   [252 252 252]
#   ...
#   [102 102 102]
#   [ 88  88  88]
#   [ 68  68  68]]
#
#  [[252 252 252]
#   [243 243 243]
#   [242 242 242]
#   ...
#   [187 187 187]
#   [173 173 173]
#   [149 149 149]]
#
#  [[233 233 233]
#   [239 239 239]
#   [253 253 253]
#   ...
#   [205 205 205]
#   [206 206 206]
#   [206 206 206]]]
# kapil dev6.png
# ./dataset/cropped/kapil dev/kapil dev6.png
# None
# None
# [[[ 29  27  33]
#   [ 30  28  34]
#   [ 33  36  41]
#   ...
#   [ 68  81  89]
#   [102 103 113]
#   [ 82  65  78]]
#
#  [[ 34  32  38]
#   [ 28  26  32]
#   [ 36  39  44]
#   ...
#   [ 53  69  76]
#   [ 60  62  72]
#   [ 44  34  46]]
#
#  [[ 49  47  53]
#   [ 38  36  42]
#   [ 14  17  22]
#   ...
#   [ 54  67  75]
#   [ 29  35  42]
#   [ 32  27  36]]
#
#  ...
#
#  [[168  61  57]
#   [162  64  54]
#   [157  65  54]
#   ...
#   [159  55  66]
#   [161  59  70]
#   [159  57  68]]
#
#  [[160  55  52]
#   [155  57  51]
#   [148  59  49]
#   ...
#   [161  57  68]
#   [160  58  69]
#   [159  57  68]]
#
#  [[158  57  55]
#   [151  59  54]
#   [144  61  53]
#   ...
#   [157  59  71]
#   [157  57  69]
#   [158  58  70]]]
# kapil dev7.png
# ./dataset/cropped/kapil dev/kapil dev7.png
# None
# None
# None
# [[[ 12   8   7]
#   [ 17  12  11]
#   [ 18  14  13]
#   ...
#   [ 53  67  56]
#   [ 71  88  75]
#   [ 71  89  76]]
#
#  [[ 20  18  18]
#   [ 30  25  26]
#   [ 32  30  30]
#   ...
#   [ 44  55  47]
#   [ 73  87  76]
#   [ 70  86  75]]
#
#  [[ 18  16  16]
#   [ 23  21  21]
#   [ 26  24  24]
#   ...
#   [ 27  35  28]
#   [ 58  69  61]
#   [ 69  82  74]]
#
#  ...
#
#  [[194 183 191]
#   [210 199 207]
#   [213 202 210]
#   ...
#   [254 255 245]
#   [254 255 245]
#   [252 255 245]]
#
#  [[193 182 190]
#   [207 196 204]
#   [210 199 207]
#   ...
#   [253 254 244]
#   [253 254 244]
#   [252 255 245]]
#
#  [[197 184 192]
#   [206 195 203]
#   [210 199 207]
#   ...
#   [253 254 244]
#   [253 254 244]
#   [251 254 245]]]
# kapil dev8.png
# ./dataset/cropped/kapil dev/kapil dev8.png
# [[[ 83  83 101]
#   [ 76  76  92]
#   [ 82  82  98]
#   ...
#   [121 142 150]
#   [ 91 111 116]
#   [ 64  84  85]]
#
#  [[ 77  79  97]
#   [ 92  95 110]
#   [ 99 102 117]
#   ...
#   [ 88 111 119]
#   [ 30  51  53]
#   [ 26  47  44]]
#
#  [[ 80  82 100]
#   [114 117 132]
#   [133 136 151]
#   ...
#   [ 65  88  96]
#   [ 13  35  33]
#   [ 28  50  45]]
#
#  ...
#
#  [[ 79  62  73]
#   [ 37  26  46]
#   [ 52  47  76]
#   ...
#   [ 52  62  80]
#   [ 44  55  69]
#   [ 41  54  68]]
#
#  [[ 81  65  66]
#   [ 55  42  50]
#   [ 37  30  45]
#   ...
#   [ 47  57  74]
#   [ 52  63  77]
#   [ 49  62  76]]
#
#  [[ 87  68  60]
#   [ 77  65  61]
#   [ 42  34  35]
#   ...
#   [ 35  46  60]
#   [ 51  63  75]
#   [ 49  62  76]]]
# kapil dev9.png
# ./dataset/cropped/kapil dev/kapil dev9.png
# None
# None
# None
# None
# None
# None
# [[[ 63  49  73]
#   [ 65  49  73]
#   [ 69  53  77]
#   ...
#   [179 186  52]
#   [177 184  50]
#   [173 182  48]]
#
#  [[ 58  44  68]
#   [ 61  45  69]
#   [ 67  51  75]
#   ...
#   [183 187  58]
#   [180 185  56]
#   [176 183  56]]
#
#  [[ 80  66  90]
#   [ 71  55  79]
#   [ 74  58  82]
#   ...
#   [186 188  65]
#   [183 186  63]
#   [179 184  63]]
#
#  ...
#
#  [[ 53  69 105]
#   [ 55  69 105]
#   [ 53  69 106]
#   ...
#   [160 141 156]
#   [160 142 159]
#   [162 144 161]]
#
#  [[ 50  68 105]
#   [ 52  68 105]
#   [ 52  67 106]
#   ...
#   [137 114 129]
#   [144 121 136]
#   [149 127 145]]
#
#  [[ 64  81 124]
#   [ 64  80 123]
#   [ 55  71 113]
#   ...
#   [122  93 109]
#   [170 141 157]
#   [157 130 146]]]
# kapil dev10.png
# ./dataset/cropped/kapil dev/kapil dev10.png
# None
# [[[114 134 139]
#   [ 95 111 117]
#   [114 126 132]
#   ...
#   [232 237 236]
#   [209 211 212]
#   [184 186 187]]
#
#  [[129 148 153]
#   [134 150 156]
#   [111 123 129]
#   ...
#   [226 231 230]
#   [218 220 221]
#   [197 199 200]]
#
#  [[140 156 162]
#   [120 134 140]
#   [119 129 136]
#   ...
#   [218 223 222]
#   [224 226 227]
#   [216 218 219]]
#
#  ...
#
#  [[207 182 166]
#   [186 161 145]
#   [220 198 180]
#   ...
#   [189 147 142]
#   [255 229 227]
#   [217 184 181]]
#
#  [[195 170 154]
#   [177 152 136]
#   [242 220 202]
#   ...
#   [201 159 154]
#   [217 179 175]
#   [239 204 201]]
#
#  [[171 146 130]
#   [216 191 175]
#   [205 183 165]
#   ...
#   [223 178 174]
#   [204 164 159]
#   [230 193 189]]]
# kapil dev11.png
# ./dataset/cropped/kapil dev/kapil dev11.png
# [[[43 37 48]
#   [40 36 42]
#   [23 16 23]
#   ...
#   [21 21 33]
#   [20 20 32]
#   [14 14 28]]
#
#  [[46 40 51]
#   [38 34 40]
#   [29 22 29]
#   ...
#   [27 27 41]
#   [32 32 46]
#   [25 24 40]]
#
#  [[40 34 45]
#   [27 20 27]
#   [36 28 35]
#   ...
#   [34 33 49]
#   [35 34 50]
#   [28 28 46]]
#
#  ...
#
#  [[10 12 30]
#   [11 13 31]
#   [11 13 31]
#   ...
#   [ 6  8  9]
#   [ 5  7  8]
#   [ 8  8  8]]
#
#  [[10 12 30]
#   [11 13 31]
#   [12 13 33]
#   ...
#   [12 11 13]
#   [11 11 11]
#   [11 11 11]]
#
#  [[ 9 13 32]
#   [10 14 33]
#   [10 13 34]
#   ...
#   [17 15 15]
#   [16 14 14]
#   [16 14 14]]]
# kapil dev12.png
# ./dataset/cropped/kapil dev/kapil dev12.png
# [[[16 18 29]
#   [14 20 31]
#   [11 16 31]
#   ...
#   [ 0  0  8]
#   [11 10 19]
#   [ 8  6 12]]
#
#  [[22 24 35]
#   [19 25 36]
#   [28 33 48]
#   ...
#   [ 0  0  9]
#   [12  9 18]
#   [ 7  5 11]]
#
#  [[25 27 38]
#   [15 21 32]
#   [37 42 57]
#   ...
#   [ 0  0 10]
#   [ 8  5 14]
#   [ 6  4 10]]
#
#  ...
#
#  [[ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]
#   ...
#   [ 4  4 16]
#   [ 4  5 15]
#   [ 1  2 12]]
#
#  [[ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]
#   ...
#   [ 5  6 16]
#   [ 5  5 17]
#   [ 3  3 15]]
#
#  [[ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]
#   ...
#   [ 3  5 13]
#   [ 4  4 16]
#   [ 4  3 19]]]
# kapil dev13.png
# ./dataset/cropped/kapil dev/kapil dev13.png
# None
# None
# None
# None
# None
# None
# [[[212 193 188]
#   [216 197 192]
#   [187 173 167]
#   ...
#   [  4   5   3]
#   [  3   4   2]
#   [  3   4   2]]
#
#  [[223 204 199]
#   [220 201 196]
#   [176 162 156]
#   ...
#   [  4   5   3]
#   [  3   4   2]
#   [  3   4   2]]
#
#  [[224 205 200]
#   [220 201 196]
#   [186 172 166]
#   ...
#   [  4   5   3]
#   [  3   4   2]
#   [  3   4   2]]
#
#  ...
#
#  [[245 242 244]
#   [248 245 247]
#   [250 247 249]
#   ...
#   [ 83  90 105]
#   [ 81  88 103]
#   [ 79  86 101]]
#
#  [[245 242 244]
#   [247 244 246]
#   [250 247 249]
#   ...
#   [ 82  89 104]
#   [ 81  88 103]
#   [ 80  87 102]]
#
#  [[244 241 243]
#   [247 244 246]
#   [249 246 248]
#   ...
#   [ 80  87 102]
#   [ 81  88 103]
#   [ 82  89 104]]]
# kapil dev14.png
# ./dataset/cropped/kapil dev/kapil dev14.png
# [[[205 201 196]
#   [ 63  54  50]
#   [ 32  21  17]
#   ...
#   [191 172 175]
#   [255 240 241]
#   [107  92  90]]
#
#  [[237 231 226]
#   [147 138 134]
#   [115 103  99]
#   ...
#   [159 140 143]
#   [135 117 118]
#   [127 112 110]]
#
#  [[180 174 169]
#   [107  98  94]
#   [165 153 149]
#   ...
#   [105  86  89]
#   [124 106 107]
#   [198 183 181]]
#
#  ...
#
#  [[247 248 244]
#   [246 245 247]
#   [243 240 255]
#   ...
#   [196 218 213]
#   [195 217 212]
#   [196 216 211]]
#
#  [[250 251 247]
#   [246 245 247]
#   [243 242 251]
#   ...
#   [198 221 213]
#   [198 221 213]
#   [197 220 212]]
#
#  [[254 255 253]
#   [249 249 249]
#   [247 246 250]
#   ...
#   [200 223 215]
#   [200 223 215]
#   [198 221 213]]]
# kapil dev15.png
# ./dataset/cropped/kapil dev/kapil dev15.png
# [[[ 29  20  16]
#   [ 28  20  13]
#   [ 23  14  10]
#   ...
#   [  4   4   4]
#   [  5   5   5]
#   [  5   6   4]]
#
#  [[ 23  16  13]
#   [ 21  15  10]
#   [ 17  10   7]
#   ...
#   [  5   5   5]
#   [  6   6   6]
#   [  6   7   5]]
#
#  [[ 15  11  10]
#   [ 14  11   7]
#   [ 11   7   6]
#   ...
#   [  6   6   6]
#   [  6   6   6]
#   [  7   8   6]]
#
#  ...
#
#  [[225 218 223]
#   [226 219 224]
#   [221 214 219]
#   ...
#   [250 255 246]
#   [255 255 247]
#   [255 255 247]]
#
#  [[226 219 224]
#   [226 219 224]
#   [221 214 219]
#   ...
#   [250 255 246]
#   [255 255 247]
#   [255 255 247]]
#
#  [[217 210 215]
#   [221 214 219]
#   [230 223 228]
#   ...
#   [249 254 245]
#   [252 253 244]
#   [251 252 243]]]
# kapil dev16.png
# ./dataset/cropped/kapil dev/kapil dev16.png
# [[[ 61  67  66]
#   [ 60  66  65]
#   [ 52  58  57]
#   ...
#   [ 44  49  50]
#   [ 37  42  43]
#   [ 31  36  37]]
#
#  [[ 53  59  58]
#   [ 58  64  63]
#   [ 54  60  59]
#   ...
#   [ 40  45  46]
#   [ 36  41  42]
#   [ 30  35  36]]
#
#  [[ 42  48  47]
#   [ 52  58  57]
#   [ 53  59  58]
#   ...
#   [ 35  40  41]
#   [ 34  39  40]
#   [ 30  35  36]]
#
#  ...
#
#  [[ 77  88  86]
#   [ 92 103 101]
#   [ 97 111 107]
#   ...
#   [ 10  13  18]
#   [ 10  13  18]
#   [ 10  13  18]]
#
#  [[ 96 107 105]
#   [107 118 116]
#   [111 122 119]
#   ...
#   [ 10  13  18]
#   [ 10  13  18]
#   [ 10  13  18]]
#
#  [[107 118 116]
#   [113 124 122]
#   [114 125 122]
#   ...
#   [ 10  13  18]
#   [ 10  13  18]
#   [ 10  13  18]]]
# kapil dev17.png
# ./dataset/cropped/kapil dev/kapil dev17.png
# [[[ 15  13  19]
#   [  6   4  10]
#   [ 13  11  17]
#   ...
#   [ 44  43  52]
#   [ 35  34  43]
#   [ 27  27  33]]
#
#  [[ 27  25  31]
#   [ 18  16  22]
#   [ 12  10  16]
#   ...
#   [ 33  32  41]
#   [ 30  29  38]
#   [ 24  24  30]]
#
#  [[ 35  33  39]
#   [ 37  35  41]
#   [ 36  34  40]
#   ...
#   [ 26  25  34]
#   [ 30  29  38]
#   [ 28  28  34]]
#
#  ...
#
#  [[ 66  49  53]
#   [ 67  52  56]
#   [ 56  45  48]
#   ...
#   [185 188 196]
#   [193 195 205]
#   [212 214 224]]
#
#  [[ 63  46  50]
#   [ 66  51  55]
#   [ 57  46  49]
#   ...
#   [198 200 208]
#   [193 195 205]
#   [195 197 207]]
#
#  [[ 63  46  50]
#   [ 64  49  53]
#   [ 57  46  49]
#   ...
#   [213 214 224]
#   [206 208 218]
#   [199 201 211]]]
# kapil dev18.png
# ./dataset/cropped/kapil dev/kapil dev18.png
# None
# [[[106 112 111]
#   [ 88  94  93]
#   [ 97 103 102]
#   ...
#   [ 22  28  27]
#   [ 26  29  33]
#   [ 45  48  52]]
#
#  [[ 70  76  75]
#   [ 98 104 103]
#   [103 109 108]
#   ...
#   [ 32  38  37]
#   [ 33  36  40]
#   [ 49  52  56]]
#
#  [[ 57  63  62]
#   [ 85  91  90]
#   [ 85  91  90]
#   ...
#   [ 34  40  39]
#   [ 30  33  37]
#   [ 43  46  50]]
#
#  ...
#
#  [[ 73  78  81]
#   [ 79  90  88]
#   [ 92 106 100]
#   ...
#   [ 10  13  18]
#   [ 10  13  18]
#   [ 10  13  18]]
#
#  [[104 109 112]
#   [102 113 111]
#   [105 119 113]
#   ...
#   [ 10  13  18]
#   [ 10  13  18]
#   [ 10  13  18]]
#
#  [[122 127 130]
#   [112 120 119]
#   [106 117 114]
#   ...
#   [ 10  13  18]
#   [ 10  13  18]
#   [ 10  13  18]]]
# kapil dev19.png
# ./dataset/cropped/kapil dev/kapil dev19.png
# None
# [[[23 28 27]
#   [18 23 22]
#   [18 23 22]
#   ...
#   [25 30 29]
#   [26 30 32]
#   [26 30 32]]
#
#  [[29 33 34]
#   [24 28 30]
#   [24 28 30]
#   ...
#   [26 31 30]
#   [25 30 29]
#   [24 29 28]]
#
#  [[31 35 37]
#   [32 36 38]
#   [33 37 39]
#   ...
#   [26 32 29]
#   [26 32 29]
#   [25 31 28]]
#
#  ...
#
#  [[31 34 38]
#   [39 42 46]
#   [45 48 52]
#   ...
#   [15 17 23]
#   [15 17 23]
#   [15 17 23]]
#
#  [[43 46 50]
#   [51 54 58]
#   [55 59 63]
#   ...
#   [15 17 23]
#   [15 17 23]
#   [15 17 23]]
#
#  [[52 55 59]
#   [57 60 64]
#   [59 62 66]
#   ...
#   [15 17 23]
#   [15 17 23]
#   [15 17 23]]]
# kapil dev20.png
# ./dataset/cropped/kapil dev/kapil dev20.png
# maria sharapova
# None
# None
# None
# [[[ 0 11 29]
#   [ 0  8 22]
#   [ 1  7 18]
#   ...
#   [19 30 58]
#   [23 34 62]
#   [19 28 55]]
#
#  [[ 2 15 31]
#   [ 0  6 20]
#   [ 5 11 22]
#   ...
#   [23 35 63]
#   [26 37 65]
#   [18 27 54]]
#
#  [[ 3 16 32]
#   [12 21 34]
#   [21 27 38]
#   ...
#   [16 28 56]
#   [17 29 57]
#   [17 28 55]]
#
#  ...
#
#  [[12 14 25]
#   [14 16 27]
#   [14 16 26]
#   ...
#   [23 41 42]
#   [36 54 55]
#   [15 28 30]]
#
#  [[13 15 26]
#   [14 16 27]
#   [14 16 26]
#   ...
#   [17 35 36]
#   [34 52 53]
#   [16 31 33]]
#
#  [[13 18 27]
#   [13 18 27]
#   [14 16 26]
#   ...
#   [ 5 25 26]
#   [29 47 48]
#   [21 36 38]]]
# Generating cropped images in folder : ./dataset/cropped/maria sharapova
# maria sharapova1.png
# ./dataset/cropped/maria sharapova/maria sharapova1.png
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [[[160 162 162]
#   [158 162 163]
#   [157 162 163]
#   ...
#   [118 128 145]
#   [146 152 165]
#   [159 161 172]]
#
#  [[158 163 162]
#   [158 162 163]
#   [157 162 165]
#   ...
#   [111 123 141]
#   [129 138 152]
#   [149 153 164]]
#
#  [[158 163 162]
#   [158 162 163]
#   [155 162 165]
#   ...
#   [106 120 139]
#   [112 122 139]
#   [139 145 158]]
#
#  ...
#
#  [[155 157 167]
#   [157 163 174]
#   [157 168 182]
#   ...
#   [138 174 210]
#   [152 187 221]
#   [141 172 203]]
#
#  [[ 92  91 100]
#   [ 93  95 106]
#   [ 86  93 108]
#   ...
#   [140 176 212]
#   [156 191 225]
#   [141 172 203]]
#
#  [[ 20  19  28]
#   [  8  10  20]
#   [  0   1  14]
#   ...
#   [142 178 214]
#   [161 196 230]
#   [143 174 205]]]
# maria sharapova2.png
# ./dataset/cropped/maria sharapova/maria sharapova2.png
# None
# None
# None
# None
# None
# [[[216 218 218]
#   [220 222 223]
#   [213 217 218]
#   ...
#   [133 151 134]
#   [118 137 118]
#   [117 136 115]]
#
#  [[220 220 220]
#   [222 221 223]
#   [219 220 224]
#   ...
#   [119 138 119]
#   [121 137 119]
#   [121 137 119]]
#
#  [[222 220 220]
#   [222 221 223]
#   [222 223 227]
#   ...
#   [119 138 117]
#   [123 137 119]
#   [122 135 119]]
#
#  ...
#
#  [[237 228 224]
#   [238 229 225]
#   [238 229 226]
#   ...
#   [167 187 242]
#   [157 178 230]
#   [157 185 232]]
#
#  [[235 226 223]
#   [233 224 221]
#   [232 224 224]
#   ...
#   [158 178 233]
#   [162 179 235]
#   [158 181 231]]
#
#  [[233 225 225]
#   [235 227 228]
#   [234 228 229]
#   ...
#   [157 178 233]
#   [163 180 236]
#   [161 182 233]]]
# maria sharapova3.png
# ./dataset/cropped/maria sharapova/maria sharapova3.png
# None
# None
# None
# [[[225 224 226]
#   [137 136 138]
#   [105 104 106]
#   ...
#   [180 179 181]
#   [163 162 164]
#   [147 146 148]]
#
#  [[209 208 210]
#   [118 117 119]
#   [ 83  82  84]
#   ...
#   [108 107 109]
#   [200 199 201]
#   [191 190 192]]
#
#  [[138 137 139]
#   [ 87  86  88]
#   [ 71  70  72]
#   ...
#   [168 167 169]
#   [147 146 148]
#   [172 171 173]]
#
#  ...
#
#  [[150 149 151]
#   [170 169 171]
#   [ 93  92  94]
#   ...
#   [170 169 171]
#   [113 112 114]
#   [143 142 144]]
#
#  [[122 121 123]
#   [194 193 195]
#   [191 190 192]
#   ...
#   [140 139 141]
#   [159 158 160]
#   [175 174 176]]
#
#  [[128 127 129]
#   [217 216 218]
#   [218 217 219]
#   ...
#   [180 179 181]
#   [164 163 165]
#   [110 109 111]]]
# maria sharapova4.png
# ./dataset/cropped/maria sharapova/maria sharapova4.png
# None
# None
# None
# None
# None
# [[[139 180 203]
#   [131 170 198]
#   [122 160 190]
#   ...
#   [142 160 171]
#   [114 136 161]
#   [118 140 168]]
#
#  [[126 170 194]
#   [120 160 189]
#   [118 157 189]
#   ...
#   [157 174 183]
#   [121 144 166]
#   [ 91 115 143]]
#
#  [[120 166 190]
#   [117 159 188]
#   [114 155 187]
#   ...
#   [180 197 206]
#   [124 147 169]
#   [109 133 161]]
#
#  ...
#
#  [[ 67  83 112]
#   [ 65  78 104]
#   [ 51  64  86]
#   ...
#   [112 128 135]
#   [ 78  84  89]
#   [ 82  85  90]]
#
#  [[ 80  98 127]
#   [ 64  79 105]
#   [ 48  62  84]
#   ...
#   [ 50  64  70]
#   [ 44  46  47]
#   [ 64  59  61]]
#
#  [[ 93 114 142]
#   [ 61  78 104]
#   [ 53  70  91]
#   ...
#   [ 29  40  44]
#   [ 54  48  49]
#   [ 57  45  45]]]
# maria sharapova5.png
# ./dataset/cropped/maria sharapova/maria sharapova5.png
# [[[231 225 214]
#   [232 226 213]
#   [233 227 216]
#   ...
#   [145 178 193]
#   [130 164 180]
#   [103 142 157]]
#
#  [[236 231 222]
#   [236 232 221]
#   [237 232 223]
#   ...
#   [124 155 170]
#   [145 179 195]
#   [129 168 183]]
#
#  [[244 236 229]
#   [242 237 228]
#   [244 236 229]
#   ...
#   [ 64  95 110]
#   [120 154 170]
#   [144 183 198]]
#
#  ...
#
#  [[242 243 241]
#   [242 243 241]
#   [242 243 241]
#   ...
#   [ 33  53  84]
#   [ 12  27  53]
#   [  9  20  40]]
#
#  [[244 242 242]
#   [242 243 241]
#   [244 242 242]
#   ...
#   [ 28  48  79]
#   [  8  23  49]
#   [  5  19  38]]
#
#  [[246 241 243]
#   [244 242 242]
#   [246 241 243]
#   ...
#   [ 10  31  59]
#   [  0  16  43]
#   [  0   8  31]]]
# maria sharapova6.png
# ./dataset/cropped/maria sharapova/maria sharapova6.png
# [[[205 208 206]
#   [204 209 208]
#   [201 209 208]
#   ...
#   [ 92 132 157]
#   [ 50  89 117]
#   [ 69 106 132]]
#
#  [[206 210 205]
#   [199 204 202]
#   [209 217 216]
#   ...
#   [ 90 130 158]
#   [ 50  92 121]
#   [ 69 109 138]]
#
#  [[206 210 205]
#   [204 209 207]
#   [202 213 211]
#   ...
#   [ 64 107 134]
#   [ 74 118 149]
#   [ 58 102 133]]
#
#  ...
#
#  [[194 213 220]
#   [204 216 226]
#   [206 213 228]
#   ...
#   [175 206 237]
#   [149 189 218]
#   [116 160 191]]
#
#  [[192 209 212]
#   [203 219 225]
#   [205 220 229]
#   ...
#   [149 191 210]
#   [126 175 197]
#   [106 156 179]]
#
#  [[194 209 212]
#   [200 216 222]
#   [201 219 226]
#   ...
#   [144 190 207]
#   [102 153 173]
#   [119 172 193]]]
# maria sharapova7.png
# ./dataset/cropped/maria sharapova/maria sharapova7.png
# None
# [[[ 17  29  57]
#   [ 18  32  61]
#   [ 26  41  73]
#   ...
#   [ 30  32  42]
#   [ 27  32  41]
#   [ 23  30  39]]
#
#  [[ 32  44  72]
#   [ 28  42  71]
#   [ 32  47  79]
#   ...
#   [ 46  48  58]
#   [ 34  39  48]
#   [ 25  32  41]]
#
#  [[ 30  41  68]
#   [ 29  43  72]
#   [ 31  46  78]
#   ...
#   [ 48  50  60]
#   [ 52  57  66]
#   [ 49  56  65]]
#
#  ...
#
#  [[ 60  62  73]
#   [ 73  79  92]
#   [ 81  88 103]
#   ...
#   [ 77 101 147]
#   [ 77 101 147]
#   [ 77 101 147]]
#
#  [[ 61  64  78]
#   [ 77  84  99]
#   [ 81  89 106]
#   ...
#   [ 76 100 146]
#   [ 76 100 146]
#   [ 76 100 146]]
#
#  [[ 73  76  90]
#   [ 75  83  96]
#   [ 54  63  77]
#   ...
#   [ 76 100 146]
#   [ 76 100 146]
#   [ 76 100 146]]]
# maria sharapova8.png
# ./dataset/cropped/maria sharapova/maria sharapova8.png
# None
# [[[218 211 202]
#   [186 188 188]
#   [157 164 167]
#   ...
#   [213 208 199]
#   [209 200 190]
#   [219 207 195]]
#
#  [[199 197 197]
#   [184 186 196]
#   [157 165 178]
#   ...
#   [216 215 211]
#   [210 204 197]
#   [231 219 209]]
#
#  [[190 188 194]
#   [165 171 184]
#   [174 181 200]
#   ...
#   [204 206 206]
#   [211 208 204]
#   [225 212 204]]
#
#  ...
#
#  [[141 172 197]
#   [114 164 187]
#   [104 158 188]
#   ...
#   [210 198 194]
#   [199 183 176]
#   [234 214 203]]
#
#  [[163 190 216]
#   [120 164 188]
#   [121 171 199]
#   ...
#   [111 102  98]
#   [160 149 141]
#   [240 223 214]]
#
#  [[106 122 145]
#   [146 175 202]
#   [142 178 208]
#   ...
#   [ 97  98  96]
#   [ 72  72  66]
#   [ 86  79  76]]]
# maria sharapova9.png
# ./dataset/cropped/maria sharapova/maria sharapova9.png
# [[[115 108 113]
#   [115 108 113]
#   [114 108 113]
#   ...
#   [100  98 110]
#   [103  96 111]
#   [110 103 118]]
#
#  [[116 109 114]
#   [116 109 114]
#   [116 109 112]
#   ...
#   [ 93  93 107]
#   [ 95  90 105]
#   [103  96 111]]
#
#  [[116 109 114]
#   [116 109 114]
#   [116 109 112]
#   ...
#   [ 86  89 104]
#   [ 89  86 101]
#   [ 95  90 105]]
#
#  ...
#
#  [[151 183 202]
#   [133 169 185]
#   [132 166 182]
#   ...
#   [168 195 215]
#   [171 197 221]
#   [148 179 202]]
#
#  [[151 184 200]
#   [133 170 184]
#   [130 166 182]
#   ...
#   [168 195 215]
#   [173 199 223]
#   [150 181 204]]
#
#  [[150 184 200]
#   [132 171 185]
#   [130 167 181]
#   ...
#   [167 194 214]
#   [176 202 226]
#   [154 185 208]]]
# maria sharapova10.png
# ./dataset/cropped/maria sharapova/maria sharapova10.png
# None
# None
# None
# None
# None
# None
# [[[ 61  51  44]
#   [ 31  19  15]
#   [ 43  31  27]
#   ...
#   [ 92 107 126]
#   [ 81  93 111]
#   [ 48  57  70]]
#
#  [[ 65  55  48]
#   [ 31  20  16]
#   [ 34  25  21]
#   ...
#   [ 74  93 114]
#   [101 116 135]
#   [ 43  54  68]]
#
#  [[ 54  44  37]
#   [ 48  39  35]
#   [ 30  24  19]
#   ...
#   [ 55  75 100]
#   [ 83  99 122]
#   [ 49  63  81]]
#
#  ...
#
#  [[ 39  30  21]
#   [ 34  28  21]
#   [ 31  29  21]
#   ...
#   [ 51  79 103]
#   [ 53  77  97]
#   [ 73  91 108]]
#
#  [[ 37  28  19]
#   [ 35  29  22]
#   [ 32  30  22]
#   ...
#   [ 54  82 106]
#   [ 46  70  90]
#   [ 62  80  97]]
#
#  [[ 35  26  17]
#   [ 35  29  22]
#   [ 33  31  21]
#   ...
#   [ 71  98 118]
#   [ 53  78  94]
#   [ 66  85  98]]]
# maria sharapova11.png
# ./dataset/cropped/maria sharapova/maria sharapova11.png
# [[[ 79 100 132]
#   [ 79 100 132]
#   [ 79 100 132]
#   ...
#   [ 82 102 137]
#   [ 79  99 134]
#   [ 80 100 135]]
#
#  [[ 80 101 133]
#   [ 80 101 133]
#   [ 80 101 132]
#   ...
#   [ 85 107 142]
#   [ 84 104 139]
#   [ 76  97 129]]
#
#  [[ 80 101 133]
#   [ 80 101 133]
#   [ 80 101 132]
#   ...
#   [ 80 102 137]
#   [ 79 101 136]
#   [ 85 106 138]]
#
#  ...
#
#  [[134 175 207]
#   [144 188 219]
#   [142 188 219]
#   ...
#   [111 126 145]
#   [ 94 117 139]
#   [ 62  89 115]]
#
#  [[134 173 205]
#   [146 187 219]
#   [147 191 222]
#   ...
#   [117 134 153]
#   [ 83 107 129]
#   [ 73 103 130]]
#
#  [[131 169 201]
#   [148 187 219]
#   [152 196 227]
#   ...
#   [117 136 157]
#   [ 71  97 121]
#   [ 95 127 156]]]
# maria sharapova12.png
# ./dataset/cropped/maria sharapova/maria sharapova12.png
# None
# None
# None
# [[[115 109 114]
#   [115 109 114]
#   [115 109 114]
#   ...
#   [ 97  95 107]
#   [ 97  95 107]
#   [ 97  95 107]]
#
#  [[115 109 114]
#   [115 109 114]
#   [115 109 114]
#   ...
#   [ 96  94 106]
#   [ 96  94 106]
#   [ 97  95 107]]
#
#  [[115 109 114]
#   [115 109 114]
#   [115 109 114]
#   ...
#   [ 95  93 105]
#   [ 95  93 105]
#   [ 97  95 107]]
#
#  ...
#
#  [[159 182 198]
#   [157 183 197]
#   [156 182 196]
#   ...
#   [174 200 224]
#   [170 198 222]
#   [173 201 225]]
#
#  [[159 182 198]
#   [156 182 196]
#   [156 182 196]
#   ...
#   [177 201 225]
#   [173 199 223]
#   [175 201 225]]
#
#  [[159 182 198]
#   [156 182 196]
#   [155 181 195]
#   ...
#   [178 202 226]
#   [175 201 225]
#   [175 201 225]]]
# maria sharapova13.png
# ./dataset/cropped/maria sharapova/maria sharapova13.png
# [[[ 76 126 144]
#   [ 98 148 166]
#   [117 167 185]
#   ...
#   [ 12  15  19]
#   [ 11  14  18]
#   [ 10  13  17]]
#
#  [[112 162 180]
#   [115 163 181]
#   [100 148 166]
#   ...
#   [ 12  15  19]
#   [ 11  14  18]
#   [ 11  14  18]]
#
#  [[102 152 170]
#   [108 156 174]
#   [106 154 172]
#   ...
#   [ 13  16  20]
#   [ 12  15  19]
#   [ 11  14  18]]
#
#  ...
#
#  [[ 93 131 173]
#   [ 92 130 172]
#   [ 92 130 172]
#   ...
#   [  6   5   7]
#   [  7   6   8]
#   [  5   7   8]]
#
#  [[ 93 131 173]
#   [ 92 130 172]
#   [ 92 130 172]
#   ...
#   [  6   5   7]
#   [  6   5   7]
#   [  5   7   8]]
#
#  [[ 91 129 171]
#   [ 90 128 170]
#   [ 92 130 172]
#   ...
#   [  6   5   7]
#   [  6   5   7]
#   [  5   7   8]]]
# maria sharapova14.png
# ./dataset/cropped/maria sharapova/maria sharapova14.png
# roger federer
# None
# [[[ 67  79 145]
#   [ 66  78 144]
#   [ 65  76 144]
#   ...
#   [ 51  72 124]
#   [ 28  49 104]
#   [ 32  52 109]]
#
#  [[ 67  79 145]
#   [ 66  78 144]
#   [ 65  76 144]
#   ...
#   [ 76  95 146]
#   [ 43  61 114]
#   [ 24  44  99]]
#
#  [[ 66  77 145]
#   [ 65  78 146]
#   [ 67  80 148]
#   ...
#   [100 113 165]
#   [ 68  80 134]
#   [ 40  53 109]]
#
#  ...
#
#  [[ 40  28  26]
#   [ 38  26  24]
#   [ 45  32  30]
#   ...
#   [125 133 162]
#   [127 135 164]
#   [128 136 165]]
#
#  [[ 39  27  25]
#   [ 38  26  24]
#   [ 45  33  29]
#   ...
#   [124 133 160]
#   [124 133 160]
#   [124 133 160]]
#
#  [[ 38  26  24]
#   [ 38  26  24]
#   [ 45  33  29]
#   ...
#   [128 139 161]
#   [127 138 160]
#   [124 134 158]]]
# Generating cropped images in folder : ./dataset/cropped/roger federer
# roger federer1.png
# ./dataset/cropped/roger federer/roger federer1.png
# None
# None
# [[[17 20 17]
#   [17 20 17]
#   [17 20 17]
#   ...
#   [40 47 53]
#   [39 48 54]
#   [42 51 59]]
#
#  [[17 20 17]
#   [17 20 17]
#   [17 20 17]
#   ...
#   [37 45 49]
#   [38 47 53]
#   [39 51 56]]
#
#  [[17 20 17]
#   [17 20 17]
#   [17 20 17]
#   ...
#   [34 42 45]
#   [33 46 49]
#   [35 49 54]]
#
#  ...
#
#  [[13 17 12]
#   [13 17 12]
#   [13 17 12]
#   ...
#   [14 15 12]
#   [15 13 11]
#   [15 13 11]]
#
#  [[13 17 12]
#   [13 17 12]
#   [13 17 12]
#   ...
#   [14 15 12]
#   [15 13 11]
#   [15 13 11]]
#
#  [[16 17 15]
#   [16 17 15]
#   [16 17 15]
#   ...
#   [15 16 14]
#   [15 13 11]
#   [15 13 11]]]
# roger federer2.png
# ./dataset/cropped/roger federer/roger federer2.png
# [[[ 59  77  88]
#   [ 58  84  91]
#   [ 50  79  86]
#   ...
#   [ 43  74  97]
#   [ 40  71  92]
#   [ 40  71  92]]
#
#  [[ 61  79  90]
#   [ 44  69  79]
#   [ 36  63  73]
#   ...
#   [ 41  73  96]
#   [ 40  73  93]
#   [ 40  73  93]]
#
#  [[ 61  79  90]
#   [ 32  54  65]
#   [ 24  49  59]
#   ...
#   [ 41  73  96]
#   [ 42  75  95]
#   [ 41  74  94]]
#
#  ...
#
#  [[146 183 221]
#   [157 191 227]
#   [154 187 220]
#   ...
#   [ 35  49  78]
#   [ 28  39  69]
#   [ 29  39  69]]
#
#  [[151 190 229]
#   [146 182 220]
#   [145 180 214]
#   ...
#   [ 31  45  74]
#   [ 28  39  69]
#   [ 29  39  69]]
#
#  [[155 195 237]
#   [147 186 225]
#   [143 181 216]
#   ...
#   [ 37  48  78]
#   [ 30  40  70]
#   [ 31  38  71]]]
# roger federer3.png
# ./dataset/cropped/roger federer/roger federer3.png
# None
# [[[ 22  24  42]
#   [ 27  31  49]
#   [ 37  41  59]
#   ...
#   [ 90  95 120]
#   [ 86  90 114]
#   [ 83  87 111]]
#
#  [[ 15  17  35]
#   [ 10  14  32]
#   [ 16  20  38]
#   ...
#   [ 91  96 121]
#   [ 88  92 116]
#   [ 85  89 113]]
#
#  [[  5   8  23]
#   [  0   1  19]
#   [  0   0  17]
#   ...
#   [ 92  97 122]
#   [ 90  94 119]
#   [ 86  90 114]]
#
#  ...
#
#  [[255 255 255]
#   [251 250 252]
#   [251 253 255]
#   ...
#   [253 238 236]
#   [250 235 233]
#   [250 232 231]]
#
#  [[255 255 254]
#   [253 251 251]
#   [252 253 255]
#   ...
#   [251 236 234]
#   [250 232 231]
#   [249 231 230]]
#
#  [[255 255 254]
#   [255 253 252]
#   [251 250 252]
#   ...
#   [249 231 230]
#   [248 230 229]
#   [248 230 229]]]
# roger federer4.png
# ./dataset/cropped/roger federer/roger federer4.png
# [[[ 42  53 103]
#   [ 37  48  98]
#   [ 39  50 100]
#   ...
#   [ 53  56  34]
#   [ 49  52  30]
#   [ 51  57  34]]
#
#  [[ 38  49  99]
#   [ 40  51 101]
#   [ 41  52 102]
#   ...
#   [ 56  60  35]
#   [ 51  55  30]
#   [ 54  58  33]]
#
#  [[ 35  46  96]
#   [ 39  50 100]
#   [ 39  50 100]
#   ...
#   [ 62  66  41]
#   [ 59  63  38]
#   [ 60  64  39]]
#
#  ...
#
#  [[ 25  29  47]
#   [ 23  29  48]
#   [ 23  29  48]
#   ...
#   [ 54  80 126]
#   [ 59  85 131]
#   [ 63  89 136]]
#
#  [[ 23  27  45]
#   [ 21  27  46]
#   [ 21  27  46]
#   ...
#   [ 59  85 132]
#   [ 65  91 138]
#   [ 68  94 141]]
#
#  [[ 22  24  42]
#   [ 20  24  42]
#   [ 20  24  42]
#   ...
#   [ 58  82 128]
#   [ 63  89 136]
#   [ 71  94 142]]]
# roger federer5.png
# ./dataset/cropped/roger federer/roger federer5.png
# [[[ 74  90 166]
#   [ 72  90 167]
#   [ 71  90 171]
#   ...
#   [ 30  39  59]
#   [ 28  36  59]
#   [ 21  28  53]]
#
#  [[ 74  91 164]
#   [ 72  90 167]
#   [ 71  91 169]
#   ...
#   [ 32  41  61]
#   [ 31  40  60]
#   [ 17  25  48]]
#
#  [[ 76  91 164]
#   [ 74  90 166]
#   [ 73  91 168]
#   ...
#   [ 24  33  53]
#   [ 24  33  53]
#   [ 22  30  53]]
#
#  ...
#
#  [[156 142 120]
#   [155 142 120]
#   [155 141 122]
#   ...
#   [247 253 222]
#   [248 253 224]
#   [248 253 226]]
#
#  [[159 143 120]
#   [157 143 121]
#   [157 142 123]
#   ...
#   [248 253 224]
#   [248 253 226]
#   [249 253 228]]
#
#  [[160 144 121]
#   [160 144 121]
#   [159 142 123]
#   ...
#   [248 253 226]
#   [248 252 227]
#   [251 254 232]]]
# roger federer6.png
# ./dataset/cropped/roger federer/roger federer6.png
# None
# [[[ 40  28  30]
#   [ 39  27  29]
#   [ 36  26  28]
#   ...
#   [  8  15  23]
#   [ 25  31  39]
#   [ 42  48  58]]
#
#  [[ 40  28  30]
#   [ 39  27  29]
#   [ 36  26  28]
#   ...
#   [  0   7  13]
#   [  6  12  20]
#   [ 25  31  39]]
#
#  [[ 40  28  30]
#   [ 39  27  29]
#   [ 36  26  28]
#   ...
#   [  9  17  22]
#   [  0   6  15]
#   [  9  16  24]]
#
#  ...
#
#  [[107  87  84]
#   [105  86  83]
#   [104  82  81]
#   ...
#   [101 133 171]
#   [102 134 172]
#   [107 138 176]]
#
#  [[109  89  88]
#   [109  89  88]
#   [104  84  83]
#   ...
#   [ 99 131 172]
#   [102 134 174]
#   [111 141 179]]
#
#  [[111  91  90]
#   [109  89  88]
#   [107  87  85]
#   ...
#   [ 99 131 172]
#   [102 134 174]
#   [112 141 182]]]
# roger federer7.png
# ./dataset/cropped/roger federer/roger federer7.png
# [[[ 88  97  94]
#   [ 89 100  97]
#   [ 92 106 105]
#   ...
#   [ 73  84  58]
#   [ 69  80  54]
#   [ 64  74  51]]
#
#  [[ 81  92  90]
#   [ 85  96  94]
#   [ 88 100 100]
#   ...
#   [ 71  83  55]
#   [ 65  76  50]
#   [ 61  72  46]]
#
#  [[ 67  76  80]
#   [ 78  87  90]
#   [ 98 106 106]
#   ...
#   [ 70  82  52]
#   [ 71  83  55]
#   [ 70  82  54]]
#
#  ...
#
#  [[177 180 185]
#   [177 180 185]
#   [165 168 173]
#   ...
#   [ 71 108 158]
#   [ 74 111 161]
#   [ 79 115 163]]
#
#  [[173 176 181]
#   [170 173 178]
#   [170 173 178]
#   ...
#   [ 67 107 155]
#   [ 67 107 155]
#   [ 69 108 153]]
#
#  [[170 173 178]
#   [166 169 174]
#   [174 177 182]
#   ...
#   [ 67 108 153]
#   [ 77 119 162]
#   [ 86 125 169]]]
# roger federer8.png
# ./dataset/cropped/roger federer/roger federer8.png
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [[[  0   0   4]
#   [ 31  33  41]
#   [ 19  22  30]
#   ...
#   [ 94 114 109]
#   [ 94 114 109]
#   [ 94 114 109]]
#
#  [[  0   0   4]
#   [ 41  40  49]
#   [ 19  21  29]
#   ...
#   [119 136 133]
#   [119 136 133]
#   [119 136 133]]
#
#  [[  4   4  10]
#   [  4   3  12]
#   [  7   9  17]
#   ...
#   [117 134 131]
#   [116 133 130]
#   [115 132 129]]
#
#  ...
#
#  [[ 59  59  23]
#   [ 58  58  22]
#   [ 58  58  22]
#   ...
#   [ 54  51   6]
#   [ 54  51   6]
#   [ 55  52   7]]
#
#  [[ 60  60  24]
#   [ 60  60  24]
#   [ 59  59  23]
#   ...
#   [ 76  73  28]
#   [ 70  67  22]
#   [ 47  44   0]]
#
#  [[ 60  60  24]
#   [ 60  60  24]
#   [ 59  59  23]
#   ...
#   [ 85  82  37]
#   [ 83  80  35]
#   [ 63  60  15]]]
# roger federer9.png
# ./dataset/cropped/roger federer/roger federer9.png
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# virat kohli
# None
# [[[ 34  33  35]
#   [ 33  24  28]
#   [ 34  33  35]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[ 22  21  21]
#   [ 22  21  21]
#   [ 34  33  35]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[ 22  21  21]
#   [ 34  33  35]
#   [ 33  24  28]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  ...
#
#  [[106 132 186]
#   [106 132 186]
#   [106 132 186]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[101 122 185]
#   [106 132 186]
#   [106 132 186]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[106 132 186]
#   [106 132 186]
#   [116 140 202]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]]
# Generating cropped images in folder : ./dataset/cropped/virat kohli
# virat kohli1.png
# ./dataset/cropped/virat kohli/virat kohli1.png
# None
# None
# [[[240 244 245]
#   [ 75  78  82]
#   [  7  11  16]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[230 234 235]
#   [ 56  59  63]
#   [ 15  19  24]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[241 245 246]
#   [ 79  82  86]
#   [ 22  25  30]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[236 161  69]
#   [241 164  68]
#   [238 170  69]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[239 160  63]
#   [240 165  63]
#   [238 162  62]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[239 168  54]
#   [241 166  68]
#   [244 167  70]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# virat kohli2.png
# ./dataset/cropped/virat kohli/virat kohli2.png
# [[[142 188 226]
#   [143 190 228]
#   [143 190 228]
#   ...
#   [131 166 204]
#   [132 167 205]
#   [132 167 205]]
#
#  [[142 188 226]
#   [143 190 228]
#   [143 190 228]
#   ...
#   [132 165 203]
#   [133 166 204]
#   [133 166 204]]
#
#  [[142 188 226]
#   [143 190 228]
#   [143 190 228]
#   ...
#   [134 164 203]
#   [134 164 203]
#   [134 164 203]]
#
#  ...
#
#  [[255 202 129]
#   [255 203 127]
#   [255 200 125]
#   ...
#   [125 115 105]
#   [125 115 105]
#   [125 115 105]]
#
#  [[255 202 129]
#   [255 203 127]
#   [255 203 127]
#   ...
#   [125 115 105]
#   [125 115 105]
#   [125 115 105]]
#
#  [[255 201 128]
#   [255 201 126]
#   [255 203 127]
#   ...
#   [125 115 105]
#   [125 115 105]
#   [125 115 105]]]
# virat kohli3.png
# ./dataset/cropped/virat kohli/virat kohli3.png
# None
# [[[ 36  30  41]
#   [ 31  24  37]
#   [ 24  17  30]
#   ...
#   [ 79 122 119]
#   [ 80 120 118]
#   [ 75 115 113]]
#
#  [[ 56  49  62]
#   [ 54  47  60]
#   [ 45  41  53]
#   ...
#   [ 81 124 121]
#   [ 84 124 122]
#   [ 79 119 117]]
#
#  [[ 78  71  84]
#   [ 80  73  88]
#   [ 70  66  78]
#   ...
#   [ 81 124 121]
#   [ 87 127 125]
#   [ 83 123 121]]
#
#  ...
#
#  [[247 250 254]
#   [249 250 254]
#   [251 250 252]
#   ...
#   [157 162 147]
#   [155 162 147]
#   [156 163 148]]
#
#  [[249 250 254]
#   [251 250 252]
#   [251 250 252]
#   ...
#   [162 167 152]
#   [159 166 151]
#   [155 162 147]]
#
#  [[247 249 250]
#   [251 248 250]
#   [252 249 251]
#   ...
#   [167 173 156]
#   [160 167 152]
#   [151 158 143]]]
# virat kohli4.png
# ./dataset/cropped/virat kohli/virat kohli4.png
# None
# None
# None
# [[[ 36  12  12]
#   [ 39  18  17]
#   [ 42  21  20]
#   ...
#   [202 202 196]
#   [200 202 196]
#   [200 202 196]]
#
#  [[ 34  10  10]
#   [ 39  15  15]
#   [ 42  21  20]
#   ...
#   [202 202 196]
#   [200 202 196]
#   [200 202 196]]
#
#  [[ 30   7   5]
#   [ 37  14  12]
#   [ 44  21  19]
#   ...
#   [200 202 196]
#   [200 202 196]
#   [200 202 196]]
#
#  ...
#
#  [[ 33   7   1]
#   [ 30   6   0]
#   [ 34   7   3]
#   ...
#   [240 234 229]
#   [240 234 229]
#   [240 234 229]]
#
#  [[ 32   5   1]
#   [ 33   6   2]
#   [ 36   9   5]
#   ...
#   [240 234 229]
#   [240 234 229]
#   [240 234 229]]
#
#  [[ 34   5   1]
#   [ 34   7   3]
#   [ 39  12   8]
#   ...
#   [240 234 229]
#   [240 234 229]
#   [240 234 229]]]
# virat kohli5.png
# ./dataset/cropped/virat kohli/virat kohli5.png
# None
# None
# None
# None
# None
# None
# None
# [[[ 90  95 110]
#   [ 91  96 111]
#   [ 85  92 107]
#   ...
#   [  0   4   3]
#   [  0   5   4]
#   [  0   6   5]]
#
#  [[ 89  96 111]
#   [ 90  97 112]
#   [ 85  94 108]
#   ...
#   [  0   4   3]
#   [  0   5   4]
#   [  0   6   5]]
#
#  [[ 90  98 111]
#   [ 90  99 112]
#   [ 86  95 108]
#   ...
#   [  0   3   4]
#   [  1   6   5]
#   [  1   6   5]]
#
#  ...
#
#  [[ 78  67  63]
#   [ 85  77  78]
#   [ 62  66  84]
#   ...
#   [115 121 134]
#   [110 116 129]
#   [106 114 127]]
#
#  [[ 76  65  61]
#   [ 90  82  82]
#   [ 67  72  87]
#   ...
#   [119 125 136]
#   [117 123 134]
#   [112 118 129]]
#
#  [[ 75  64  60]
#   [ 94  86  86]
#   [ 71  76  91]
#   ...
#   [115 120 129]
#   [118 122 133]
#   [110 116 127]]]
# virat kohli6.png
# ./dataset/cropped/virat kohli/virat kohli6.png
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [[[106  93  85]
#   [107  96  88]
#   [107 100  91]
#   ...
#   [ 13   3  20]
#   [ 19  11  21]
#   [ 32  26  31]]
#
#  [[116 103  95]
#   [110  99  91]
#   [ 99  94  85]
#   ...
#   [ 18   2  13]
#   [ 20  12  22]
#   [ 21  17  23]]
#
#  [[173 160 152]
#   [170 159 151]
#   [ 97  92  83]
#   ...
#   [ 21   2   5]
#   [ 20  12  19]
#   [  8   5  14]]
#
#  ...
#
#  [[ 82  67  58]
#   [ 82  67  58]
#   [ 85  68  59]
#   ...
#   [ 67  40  44]
#   [ 62  42  37]
#   [ 76  59  50]]
#
#  [[ 81  66  57]
#   [ 82  67  58]
#   [ 85  68  59]
#   ...
#   [ 12   0   0]
#   [ 41  25  19]
#   [ 75  58  49]]
#
#  [[ 81  66  57]
#   [ 81  66  57]
#   [ 84  67  58]
#   ...
#   [  4   0   0]
#   [ 20   8   2]
#   [ 78  61  52]]]
# virat kohli7.png
# ./dataset/cropped/virat kohli/virat kohli7.png
# None
# None
# None
# None
# [[[ 35  36  34]
#   [ 33  35  35]
#   [ 24  29  32]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[ 30  28  27]
#   [ 27  26  28]
#   [ 34  38  43]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[ 32  28  27]
#   [ 37  36  38]
#   [ 35  38  46]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[127 138 195]
#   [137 135 195]
#   [143 136 193]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[121 153 196]
#   [129 145 198]
#   [127 132 187]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[ 98 140 175]
#   [118 149 194]
#   [115 134 185]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# virat kohli8.png
# ./dataset/cropped/virat kohli/virat kohli8.png
# [[[252 252 252]
#   [252 252 252]
#   [252 252 252]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[252 252 252]
#   [252 252 252]
#   [252 252 252]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[252 252 252]
#   [252 252 252]
#   [252 252 252]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  ...
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [255 251 253]
#   [255 251 253]
#   [254 251 253]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [255 250 253]
#   [255 250 253]
#   [255 250 253]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [255 251 252]
#   [255 251 252]
#   [255 251 252]]]
# virat kohli9.png
# ./dataset/cropped/virat kohli/virat kohli9.png
# [[[ 74 134 186]
#   [ 77 134 185]
#   [ 81 135 182]
#   ...
#   [ 78 100 118]
#   [ 87 111 129]
#   [ 80 106 123]]
#
#  [[ 69 132 192]
#   [ 74 133 189]
#   [ 81 134 184]
#   ...
#   [ 82 108 120]
#   [ 84 111 125]
#   [ 77 103 119]]
#
#  [[ 65 132 195]
#   [ 72 132 192]
#   [ 83 133 185]
#   ...
#   [ 80 109 118]
#   [ 83 111 122]
#   [ 78 104 120]]
#
#  ...
#
#  [[154 184 201]
#   [153 183 202]
#   [151 183 202]
#   ...
#   [144 146 146]
#   [106 111 110]
#   [ 93  99  94]]
#
#  [[152 185 201]
#   [150 182 201]
#   [147 180 199]
#   ...
#   [125 127 127]
#   [ 97 100  98]
#   [ 94 100  95]]
#
#  [[153 186 202]
#   [149 181 200]
#   [143 176 195]
#   ...
#   [116 118 119]
#   [100 102 102]
#   [ 95  99  94]]]
# virat kohli10.png
# ./dataset/cropped/virat kohli/virat kohli10.png
# None
# [[[254 189 168]
#   [255 188 167]
#   [255 186 166]
#   ...
#   [ 38  42  60]
#   [ 43  44  58]
#   [ 44  43  53]]
#
#  [[255 188 167]
#   [254 187 166]
#   [254 185 165]
#   ...
#   [ 46  53  73]
#   [ 47  51  70]
#   [ 46  49  64]]
#
#  [[254 187 166]
#   [254 185 165]
#   [255 184 164]
#   ...
#   [ 54  66  90]
#   [ 54  62  85]
#   [ 52  59  79]]
#
#  ...
#
#  [[255 162 147]
#   [255 162 147]
#   [254 163 148]
#   ...
#   [ 30  29  38]
#   [ 46  50  61]
#   [ 37  44  61]]
#
#  [[255 162 147]
#   [255 163 148]
#   [255 164 149]
#   ...
#   [ 23  26  34]
#   [ 29  36  51]
#   [ 21  32  54]]
#
#  [[255 163 148]
#   [255 164 149]
#   [255 165 150]
#   ...
#   [ 22  26  37]
#   [ 19  25  44]
#   [ 14  24  48]]]
# virat kohli11.png
# ./dataset/cropped/virat kohli/virat kohli11.png
# None
# None
# None
# None
# None
# [[[253 253 253]
#   [253 255 255]
#   [244 246 247]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[243 243 243]
#   [253 255 255]
#   [250 252 253]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[252 252 252]
#   [244 246 247]
#   [250 252 253]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[242 255 227]
#   [234 238 179]
#   [216 205 125]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[236 247 201]
#   [212 215 136]
#   [214 203 105]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 229 173]
#   [217 205  97]
#   [216 203  75]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# virat kohli12.png
# ./dataset/cropped/virat kohli/virat kohli12.png
# [[[121 124 145]
#   [ 66  74  97]
#   [ 25  36  58]
#   ...
#   [ 85  90 111]
#   [ 62  67  88]
#   [ 50  55  76]]
#
#  [[ 73  75  99]
#   [ 50  55  80]
#   [ 30  38  61]
#   ...
#   [ 94 101 120]
#   [ 77  82 103]
#   [ 64  70  89]]
#
#  [[ 43  47  71]
#   [ 38  45  70]
#   [ 34  42  65]
#   ...
#   [ 80  90 114]
#   [ 62  71  98]
#   [ 47  57  81]]
#
#  ...
#
#  [[133 171 173]
#   [127 164 168]
#   [124 161 165]
#   ...
#   [129 157 217]
#   [150 179 240]
#   [124 155 218]]
#
#  [[134 172 174]
#   [130 167 171]
#   [128 165 169]
#   ...
#   [143 170 226]
#   [134 163 220]
#   [126 155 216]]
#
#  [[132 171 173]
#   [132 169 173]
#   [132 169 173]
#   ...
#   [153 177 229]
#   [139 165 219]
#   [151 178 235]]]
# virat kohli13.png
# ./dataset/cropped/virat kohli/virat kohli13.png
# None
# None
# None
# None
# None
# None
# [[[ 55  27  27]
#   [ 56  28  28]
#   [ 56  28  28]
#   ...
#   [ 88  56  61]
#   [ 88  56  61]
#   [ 88  56  61]]
#
#  [[ 55  27  27]
#   [ 56  28  28]
#   [ 56  28  28]
#   ...
#   [ 88  56  61]
#   [ 88  56  61]
#   [ 88  56  61]]
#
#  [[ 55  27  27]
#   [ 56  28  28]
#   [ 56  28  28]
#   ...
#   [ 89  57  62]
#   [ 88  56  61]
#   [ 88  56  61]]
#
#  ...
#
#  [[ 91  59  64]
#   [ 91  59  64]
#   [ 91  59  64]
#   ...
#   [100  66  72]
#   [100  66  72]
#   [100  66  72]]
#
#  [[ 91  59  64]
#   [ 91  59  64]
#   [ 91  59  64]
#   ...
#   [100  66  72]
#   [100  66  72]
#   [100  66  72]]
#
#  [[ 91  59  64]
#   [ 91  59  64]
#   [ 91  59  64]
#   ...
#   [100  66  72]
#   [100  66  72]
#   [100  66  72]]]
# virat kohli14.png
# ./dataset/cropped/virat kohli/virat kohli14.png
# None
# None
# None
# [[[ 61  76 102]
#   [ 48  63  89]
#   [ 34  49  75]
#   ...
#   [ 79  85  92]
#   [ 83  86  90]
#   [ 81  83  84]]
#
#  [[ 69  86 112]
#   [ 43  58  84]
#   [ 31  46  72]
#   ...
#   [ 77  81  86]
#   [ 78  80  81]
#   [ 74  74  74]]
#
#  [[ 58  77 104]
#   [ 32  49  76]
#   [ 29  46  73]
#   ...
#   [ 63  66  70]
#   [ 86  88  89]
#   [ 83  81  80]]
#
#  ...
#
#  [[205 229 247]
#   [114 137 159]
#   [ 22  43  65]
#   ...
#   [125 106  99]
#   [127 105  99]
#   [128 107  99]]
#
#  [[202 229 249]
#   [133 159 183]
#   [ 33  57  81]
#   ...
#   [125 106 103]
#   [126 105 103]
#   [126 106 101]]
#
#  [[202 233 254]
#   [150 179 206]
#   [ 80 107 134]
#   ...
#   [123 105 106]
#   [126 106 105]
#   [126 106 105]]]
# virat kohli15.png
# ./dataset/cropped/virat kohli/virat kohli15.png
# None
# [[[233 234 232]
#   [247 248 246]
#   [242 243 241]
#   ...
#   [163 170 233]
#   [165 173 233]
#   [169 174 235]]
#
#  [[247 248 246]
#   [248 249 247]
#   [248 249 247]
#   ...
#   [163 171 231]
#   [165 173 233]
#   [169 175 234]]
#
#  [[249 250 248]
#   [242 243 241]
#   [241 242 240]
#   ...
#   [170 177 234]
#   [171 178 235]
#   [174 179 234]]
#
#  ...
#
#  [[154  57  43]
#   [131  49  37]
#   [102  40  32]
#   ...
#   [ 22  22  38]
#   [ 20  14  31]
#   [ 27  22  24]]
#
#  [[168  69  55]
#   [146  62  50]
#   [109  46  38]
#   ...
#   [  8   5  30]
#   [  9   1  24]
#   [ 20  12  22]]
#
#  [[180  79  64]
#   [159  74  59]
#   [118  53  44]
#   ...
#   [  5   0  39]
#   [  1   0  23]
#   [  7   0  15]]]
# virat kohli16.png
# ./dataset/cropped/virat kohli/virat kohli16.png
# None
# None
# None
# None
# None
# None

# %%
#Wavelet Transform of the images
import numpy as np
import pywt
import cv2

def w2d(img,mode='haar',level=1):
    imArray=img
    #Datatype Conversion
    #convert to grayscale
    imArray=cv2.cvtColor(imArray,cv2.COLOR_RGB2GRAY)
    #convert to float
    imArray=np.float32(imArray)
    imArray /=255
    #compute coefficients
    coeffs=pywt.wavedec2(imArray,mode,level=level)
    
    #process coefficient
    coeffs_H=list(coeffs)
    coeffs_H[0]*=0
    
    #reconstruction
    imArray_H=pywt.waverec2(coeffs_H,mode)
    imArray_H *= 255
    imArray_H = np.uint8(imArray_H)
    
    return imArray_H

# %%
cropped_image
# Out:
# array([[[212, 193, 188],
#         [216, 197, 192],
#         [187, 173, 167],
#         ...,
#         [  4,   5,   3],
#         [  3,   4,   2],
#         [  3,   4,   2]],
#
#        [[223, 204, 199],
#         [220, 201, 196],
#         [176, 162, 156],
#         ...,
#         [  4,   5,   3],
#         [  3,   4,   2],
#         [  3,   4,   2]],
#
#        [[224, 205, 200],
#         [220, 201, 196],
#         [186, 172, 166],
#         ...,
#         [  4,   5,   3],
#         [  3,   4,   2],
#         [  3,   4,   2]],
#
#        ...,
#
#        [[245, 242, 244],
#         [248, 245, 247],
#         [250, 247, 249],
#         ...,
#         [ 83,  90, 105],
#         [ 81,  88, 103],
#         [ 79,  86, 101]],
#
#        [[245, 242, 244],
#         [247, 244, 246],
#         [250, 247, 249],
#         ...,
#         [ 82,  89, 104],
#         [ 81,  88, 103],
#         [ 80,  87, 102]],
#
#        [[244, 241, 243],
#         [247, 244, 246],
#         [249, 246, 248],
#         ...,
#         [ 80,  87, 102],
#         [ 81,  88, 103],
#         [ 82,  89, 104]]], dtype=uint8)

# %%
im_har=w2d(cropped_image,'db1',5)
plt.imshow(im_har,cmap='gray')

# %%
im_har.shape
# Out:
# (252, 252)

# %%
celebrity_file_names_dict
# Out:
# {'brian lara': ['./dataset/cropped/brian lara/brian lara1.png',
#   './dataset/cropped/brian lara/brian lara2.png',
#   './dataset/cropped/brian lara/brian lara3.png',
#   './dataset/cropped/brian lara/brian lara4.png',
#   './dataset/cropped/brian lara/brian lara5.png',
#   './dataset/cropped/brian lara/brian lara6.png',
#   './dataset/cropped/brian lara/brian lara7.png'],
#  'kapil dev': ['./dataset/cropped/kapil dev/kapil dev1.png',
#   './dataset/cropped/kapil dev/kapil dev2.png',
#   './dataset/cropped/kapil dev/kapil dev3.png',
#   './dataset/cropped/kapil dev/kapil dev4.png',
#   './dataset/cropped/kapil dev/kapil dev5.png',
#   './dataset/cropped/kapil dev/kapil dev6.png',
#   './dataset/cropped/kapil dev/kapil dev7.png',
#   './dataset/cropped/kapil dev/kapil dev8.png',
#   './dataset/cropped/kapil dev/kapil dev9.png',
#   './dataset/cropped/kapil dev/kapil dev10.png',
#   './dataset/cropped/kapil dev/kapil dev11.png',
#   './dataset/cropped/kapil dev/kapil dev12.png',
#   './dataset/cropped/kapil dev/kapil dev13.png',
#   './dataset/cropped/kapil dev/kapil dev14.png',
#   './dataset/cropped/kapil dev/kapil dev15.png',
#   './dataset/cropped/kapil dev/kapil dev16.png',
#   './dataset/cropped/kapil dev/kapil dev17.png',
#   './dataset/cropped/kapil dev/kapil dev18.png',
#   './dataset/cropped/kapil dev/kapil dev19.png',
#   './dataset/cropped/kapil dev/kapil dev20.png'],
#  'maria sharapova': ['./dataset/cropped/maria sharapova/maria sharapova1.png',
#   './dataset/cropped/maria sharapova/maria sharapova2.png',
#   './dataset/cropped/maria sharapova/maria sharapova3.png',
#   './dataset/cropped/maria sharapova/maria sharapova4.png',
#   './dataset/cropped/maria sharapova/maria sharapova5.png',
#   './dataset/cropped/maria sharapova/maria sharapova6.png',
#   './dataset/cropped/maria sharapova/maria sharapova7.png',
#   './dataset/cropped/maria sharapova/maria sharapova8.png',
#   './dataset/cropped/maria sharapova/maria sharapova9.png',
#   './dataset/cropped/maria sharapova/maria sharapova10.png',
#   './dataset/cropped/maria sharapova/maria sharapova11.png',
#   './dataset/cropped/maria sharapova/maria sharapova12.png',
#   './dataset/cropped/maria sharapova/maria sharapova13.png',
#   './dataset/cropped/maria sharapova/maria sharapova14.png'],
#  'roger federer': ['./dataset/cropped/roger federer/roger federer1.png',
#   './dataset/cropped/roger federer/roger federer2.png',
#   './dataset/cropped/roger federer/roger federer3.png',
#   './dataset/cropped/roger federer/roger federer4.png',
#   './dataset/cropped/roger federer/roger federer5.png',
#   './dataset/cropped/roger federer/roger federer6.png',
#   './dataset/cropped/roger federer/roger federer7.png',
#   './dataset/cropped/roger federer/roger federer8.png',
#   './dataset/cropped/roger federer/roger federer9.png'],
#  'virat kohli': ['./dataset/cropped/virat kohli/virat kohli1.png',
#   './dataset/cropped/virat kohli/virat kohli2.png',
#   './dataset/cropped/virat kohli/virat kohli3.png',
#   './dataset/cropped/virat kohli/virat kohli4.png',
#   './dataset/cropped/virat kohli/virat kohli5.png',
#   './dataset/cropped/virat kohli/virat kohli6.png',
#   './dataset/cropped/virat kohli/virat kohli7.png',
#   './dataset/cropped/virat kohli/virat kohli8.png',
#   './dataset/cropped/virat kohli/virat kohli9.png',
#   './dataset/cropped/virat kohli/virat kohli10.png',
#   './dataset/cropped/virat kohli/virat kohli11.png',
#   './dataset/cropped/virat kohli/virat kohli12.png',
#   './dataset/cropped/virat kohli/virat kohli13.png',
#   './dataset/cropped/virat kohli/virat kohli14.png',
#   './dataset/cropped/virat kohli/virat kohli15.png',
#   './dataset/cropped/virat kohli/virat kohli16.png']}

# %%
class_dict={'brian_lara':0,
            'kapil_dev':1,
            'maria_sharapova':2,
            'roger_federer':3,
            'virat_kohli':4}

# %%
X,y=[],[]

for celebrity_name,training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img=cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img=cv2.resize(img,(32,32))
        img_har=w2d(img,'db1',5)
        scalled_img_har=cv2.resize(img_har,(32,32))
        combined_img=np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3+32*32
# Out:
# 4096

# %%
X=np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (63, 4096)

# %%
X[0].shape
# Out:
# (4096,)

# %%
# Out:
# 63

# %% [markdown]
# ### Data Cleaning is done, now train the model

# %% [markdown]
# we will use svm with rbf kernel tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
pipe=Pipeline([('scaler',StandardScaler()),('svc',SVC(kernel='rbf',C=10))])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.625

# %%
len(X_test)
# Out:
# 16

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.29      1.00      0.44         2
#            2       1.00      0.67      0.80         6
#            3       0.00      0.00      0.00         2
#            4       1.00      0.75      0.86         4
#
#     accuracy                           0.62        16
#    macro avg       0.66      0.58      0.55        16
# weighted avg       0.79      0.62      0.65        16

# %% [markdown]
# ### Hyperparameter tuning using GridSearchCV

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params={
    'svm':{
        'model':svm.SVC(gamma='auto',probability=True),
        'params':{
            'svc__C':[1,10,100,1000],
            'svc__kernel':['rbf','linear']
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'randomforestclassifier__n_estimators':[1,5,10]
        }
    },
    'logistic_regression':{
        'model':LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'logisticregression__C':[1,5,10]
        }
    }
}

# %%
score=[]
best_estimators={}
import pandas as pd
for algo,mp in model_params.items():
    pipe=make_pipeline(StandardScaler(),mp['model'])
    clf=GridSearchCV(pipe,mp['params'],cv=5,return_train_score=True)
    clf.fit(X_train,y_train)
    score.append({
        'model':algo,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })
    best_estimators[algo]=clf.best_estimator_
    
df=pd.DataFrame(score,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.871111
# 1        random_forest    0.724444
# 2  logistic_regression    0.704444
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.625

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6875

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.6875

# %%
best_clf=best_estimators['svm']

# %%
best_clf
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc',
#                  SVC(C=1, gamma='auto', kernel='linear', probability=True))])

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,best_clf.predict(X_test))
cm
# Out:
# array([[1, 0, 0, 1, 0],
#        [0, 2, 0, 0, 0],
#        [1, 1, 4, 0, 0],
#        [0, 2, 0, 0, 0],
#        [0, 1, 0, 0, 3]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'brian lara': 0,
#  'kapil dev': 1,
#  'maria sharapova': 2,
#  'roger federer': 3,
#  'virat kohli': 4}

# %% [markdown]
# ### Save the model

# %%
import joblib
joblib.dump(best_clf,'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %% [markdown]
# ### Save Class Dictionary

# %%
import json
with open('class_dictionary.json','w') as f:
    f.write(json.dumps(class_dict))
